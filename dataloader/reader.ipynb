# %%
import SimpleITK as sitk
import os
from tqdm import tqdm
from glob import glob

# %%
data_path = '/braindat/lab/chenyd/DATASET/MSD/Task01_BrainTumour.tar'

# %%
path = '/braindat/lab/chenyd/DATASET/MSD/Task02_Heart/imagesTr/la_004.nii.gz'
def read_niigz(path):
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_10604/941612034.py in <module>
# ----> 1 data = sitk.ReadImage(data_path)
#
# /opt/conda/lib/python3.7/site-packages/SimpleITK/extra.py in ReadImage(fileName, outputPixelType, imageIO)
#     353     reader.SetImageIO(imageIO)
#     354     reader.SetOutputPixelType(outputPixelType)
# --> 355     return reader.Execute()
#     356
#     357
#
# /opt/conda/lib/python3.7/site-packages/SimpleITK/SimpleITK.py in Execute(self)
#    8436
#    8437         """
# -> 8438         return _SimpleITK.ImageFileReader_Execute(self)
#    8439
#    8440     def ReadImageInformation(self):
#
# RuntimeError: Exception thrown in SimpleITK ImageFileReader_Execute: /tmp/SimpleITK/Code/IO/src/sitkImageReaderBase.cxx:105:
# sitk::ERROR: Unable to determine ImageIO reader for "/braindat/lab/chenyd/DATASET/MSD/Task01_BrainTumour.tar"

# %%
import nibabel as nib
import numpy as np
import os
from tqdm import tqdm
from glob import glob

def read_niigz(data_path):
    img = nib.load(data_path)
    img = img.get_fdata()
    return img

# %%
data_path = '/braindat/lab/chenyd/DATASET/MSD/Task05_Prostate/imagesTr/prostate_13.nii.gz'
img = read_niigz(data_path)

# %%
img.shape
# Out:
# (320, 320, 20, 2)

# %%
from matplotlib import pyplot as plt

plt.subplot(2,2,1)
plt.imshow(img[...,0], cmap='gray')
plt.subplot(2,2,2)
plt.imshow(img[...,1], cmap='gray')
plt.subplot(2,2,3)
plt.imshow(img[...,2], cmap='gray')
plt.subplot(2,2,4)
plt.imshow(img[...,3], cmap='gray')

# %%
from PIL import Image

img_vis = Image.fromarray(img[...,0] / img.max() * 255).convert('RGB')

# %%
img.shape
# Out:
# (240, 240, 155, 4)

# %%
father_path = ['/braindat/lab/chenyd/DATASET/MSD/Task01_BrainTumour/imagesTs', '/braindat/lab/chenyd/DATASET/MSD/Task01_BrainTumour/imagesTr', '/braindat/lab/chenyd/DATASET/MSD/Task04_Hippocampus/imagesTs', '/braindat/lab/chenyd/DATASET/MSD/Task04_Hippocampus/imagesTr', '/braindat/lab/chenyd/DATASET/MSD/Task02_Heart/imagesTs', '/braindat/lab/chenyd/DATASET/MSD/Task02_Heart/imagesTr', '/braindat/lab/chenyd/DATASET/MSD/Task07_Pancreas/imagesTs', '/braindat/lab/chenyd/DATASET/MSD/Task07_Pancreas/imagesTr']

# %%
dir_name = []
for i in father_path:
    child_name = glob(os.path.join(i, '*gz'))
    dir_name += (child_name)

# %%
for i in tqdm(dir_name):
    temp_data = read_niigz(i)
    print(temp_data.shape)
# Out:
#   0%|          | 1/1199 [00:01<23:22,  1.17s/it]
# (240, 240, 155, 4)
#   0%|          | 2/1199 [00:02<24:45,  1.24s/it]
# (240, 240, 155, 4)
#   0%|          | 3/1199 [00:03<23:19,  1.17s/it]
# (240, 240, 155, 4)
#   0%|          | 4/1199 [00:04<23:49,  1.20s/it]
# (240, 240, 155, 4)
#   0%|          | 5/1199 [00:05<23:03,  1.16s/it]
# (240, 240, 155, 4)
#   1%|          | 6/1199 [00:06<22:41,  1.14s/it]
# (240, 240, 155, 4)
#   1%|          | 6/1199 [00:07<24:44,  1.24s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_17617/2366563794.py in <module>
#       1 for i in tqdm(dir_name):
# ----> 2     temp_data = read_niigz(i)
#       3     print(temp_data.shape)
#
# /tmp/ipykernel_17617/3145208117.py in read_niigz(data_path)
#       7 def read_niigz(data_path):
#       8     img = nib.load(data_path)
# ----> 9     img = img.get_fdata()
# ...

# %%
temp_data.ndim
# Out:
# 4

# %%
temp_data.shape
# Out:
# (240, 240, 155, 4)

# %%
from matplotlib import pyplot as plt

plt.subplot(2,2,1)
plt.imshow(temp_data[...,100,0], cmap='gray')
plt.subplot(2,2,2)
plt.imshow(temp_data[...,100,1], cmap='gray')
plt.subplot(2,2,3)
plt.imshow(temp_data[...,100,2], cmap='gray')
plt.subplot(2,2,4)
plt.imshow(temp_data[...,100,3], cmap='gray')

# %%
import random

# %%
a = np.random.randint(0, 100, (2, 3, 4))
need_shape = (4,4,8)
b = np.pad(a, ((0, need_shape[0] - a.shape[0]), (0, need_shape[1] - a.shape[1]), (0, need_shape[2] - a.shape[2])), 'constant', constant_values=0)

# %%
# !nvidia-smi
# Out:
# Sat Apr 29 14:34:01 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 470.63.01    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:60:00.0 Off |                  N/A |
# | 20%   31C    P2    73W / 250W |   6771MiB / 11178MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
import os
print(os.environ["RANK"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2509/785222837.py in <module>
#       1 import os
# ----> 2 print(os.environ["RANK"])
#
# /opt/conda/lib/python3.7/os.py in __getitem__(self, key)
#     679         except KeyError:
#     680             # raise KeyError with the original key value
# --> 681             raise KeyError(key) from None
#     682         return self.decodevalue(value)
#     683
#
# KeyError: 'RANK'

# %%
a = [1,2,3]
b = [0,1,20]
# 比较a中的所有元素是否大于b
c = [i > j for i, j in zip(a, b)]

# %%
*c.all()
# Out:
#   File "/tmp/ipykernel_21745/1741071529.py", line 4
# SyntaxError: can't use starred expression here
