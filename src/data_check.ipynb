# %%
import h5py
f_raw = h5py.File('/h3cstore_ns/Backbones/data/wafer36/wafer36_inputs.h5', 'r')
data = f_raw['main'][:]
print(data.shape)
f_raw.close()

# data
# Out:
# (125, 1250, 1250)

# %%
import torch

# %%
model_weights = torch.load('/h3cstore_ns/EM_pretrain/mamba_pretrain_autoregress_0428/0427segmamba_auto_mode0_fill_nose1/checkpoint-100.pth')


if isinstance(model_weights, dict):
    for name, param in model_weights.items():
        print(f'Layer Name: {name}')
        print('Weights:', param)
        print('---------------------------------------------------')
else:
    print(model_weights)
# Out:
# Layer Name: model
# Weights: OrderedDict([('vit.downsample_layers.0.0.weight', tensor([[[[[-0.1315,  0.0748, -0.0258,  ...,  0.0284, -0.1632, -0.1405],
#            [-0.1230, -0.1406,  0.1406,  ..., -0.1375, -0.0294,  0.0983],
#            [-0.0304, -0.1291, -0.0193,  ..., -0.0340, -0.0075, -0.1215],
#            ...,
#            [ 0.0636, -0.0537, -0.0887,  ...,  0.1045,  0.0241, -0.0184],
#            [ 0.0879, -0.0730, -0.0978,  ..., -0.0099,  0.0436,  0.0110],
#            [-0.0969,  0.0281,  0.0378,  ..., -0.0325, -0.0676, -0.1290]]]],
#
#
#
#         [[[[ 0.0202,  0.0482, -0.0032,  ...,  0.0883,  0.0131,  0.0876],
#            [ 0.0446,  0.0022, -0.0901,  ..., -0.0170, -0.0240, -0.0830],
#            [-0.0239, -0.1315, -0.1170,  ..., -0.0246,  0.0214, -0.0945],
#            ...,
#            [ 0.0988, -0.1028,  0.1053,  ...,  0.0730,  0.1169, -0.0273],
#            [-0.0233,  0.0825, -0.0288,  ..., -0.0234,  0.1123,  0.0388],
# ...
